# %% [markdown]
# Name:husein aljohary
#
# ID:140083

# %%
#question 1

table = {'2 * 3 =': 2*3 ,
         '2 ** 3': 2**3,
         '2 + 2 * 5':2+2*5,
         '(2 + 2) * 5 ':(2+2)*5 ,
         '-4 - -4 - -4 ':-4 - -4 - -4,
         '2 ** 2 ** 0': 2 ** 2 ** 0,
         '(2 ** 2) ** 0 ': (2 ** 2)**0,
         '4 // 2': 4 // 2,
         '5 // 2 ': 5 // 2,
         '5 // 2.0 ':float(5 // 2.0 ),
         '5.5 // 2.5 ':float(5.5 // 2.5),
         '4 / 2 ': 4 / 2,
         '5 / 2  ': 5 / 2,
         '5 / 2.0  ':float(5 / 2.0),
         '5.5 // 2.5 ':float(5.5 // 2.5),
         '5 % 2  ': 5 % 2,
         '6 % 2  ': 6 % 2,
         '8 % 3  ': 8 % 3,
         '6.2 % 4   ': float(6.2 % 4),
         '-5 % 4 ':-5 % 4 

          }
for ex, result in table.items():print(f'{ex:14} = {result:2}')
# Out:
# 2 * 3 =        =  6
# 2 ** 3         =  8
# 2 + 2 * 5      = 12
# (2 + 2) * 5    = 20
# -4 - -4 - -4   =  4
# 2 ** 2 ** 0    =  2
# (2 ** 2) ** 0  =  1
# 4 // 2         =  2
# 5 // 2         =  2
# 5 // 2.0       = 2.0
# 5.5 // 2.5     = 2.0
# 4 / 2          = 2.0
# 5 / 2          = 2.5
# 5 / 2.0        = 2.5
# 5 % 2          =  1
# 6 % 2          =  0
# 8 % 3          =  2
# 6.2 % 4        = 2.2
# -5 % 4         =  3

# %%
#question 2

table2 = {
'3 < 5':str(3 < 5 ),
'3 < 5 <= 10':str(3 < 5 <= 10),
'10 > 5 > 2':str(10 > 5 > 2),
'10 > 5 > 7':str(10 > 5 > 7),
'3 < 5 and 5 < 10':str(3 < 5 and 5 < 10),
'not(True)':str(not(True)),
'not(0)':not(0),
'not(True and False)':str(not(True and False)),
'bool(3+4) and True':str(bool(3+4) and True),
'not(True)':str(not(True)),
'not(1)':not(1),
'True and False':str(True and False),
'True or False':str(True or False),
'not True':str(not True),
'not not False':str(not not False),
'not False and True':str(not False and True),
'not (False or True)':str(not (False or True)),
'True and False and True':str(True and False and True),
'True or (False and True)':str(True or (False and True)),
'False or ( -5 % 2 == 1)':str(False or ( -5 % 2 == 1)),
'1 and 2':1 and 2,
'3 > 2 > 0':str(3 > 2 > 0),
'1 and 0':1 and 0 ,
'bool(1 and 2)':str(bool(1 and 2)),
'bool(5 and 0)' :str(bool(5 and 0))
    
          }
for ex2, result2 in table2.items():print(f'{ex2:24} = {result2:2}')
# Out:
# 3 < 5                    = True
# 3 < 5 <= 10              = True
# 10 > 5 > 2               = True
# 10 > 5 > 7               = False
# 3 < 5 and 5 < 10         = True
# not(True)                = False
# not(0)                   =  1
# not(True and False)      = True
# bool(3+4) and True       = True
# not(1)                   =  0
# True and False           = False
# True or False            = True
# not True                 = False
# not not False            = False
# not False and True       = True
# not (False or True)      = False
# True and False and True  = False
# True or (False and True) = True
# False or ( -5 % 2 == 1)  = True
# 1 and 2                  =  2
# 3 > 2 > 0                = True
# 1 and 0                  =  0
# bool(1 and 2)            = True
# bool(5 and 0)            = False

# %%
#question 3

table3 = {
    'float(4)':float(4),
    'int(5.3)':int(5.3),
    'float("4") ':float("4") ,
    'int("5") ':int("5") ,
    'int(True)':int(True),
    'float(True)':float(True),
    'int(False)':int(False),
    'float(int(5.3)) ':float(int(5.3)) ,
    'int(5.7) ':int(5.7) ,
    'float(7) // 4':float(7) // 4,
    'int(7 / 4) ':int(7 / 4) ,
    '6.2 and False ':6.2 and False ,
    'True and 6.2':True and 6.2,
    'type(4.5)':str(type(4.5)),
    'type(3)':str(type(3)),
    'type(True) ':str(type(True)) ,
    'type(False)':str(type(False)),
    'type(not 1)':str(type(not 1)),
    'type(not(0))':str(type(not(0))),
    'type(True and 3) ':str(type(True and 3)) ,
    'type(None)':str(type(None)),
    'type([]) ':str(type([])) ,
    'type(()) ':str(type(())) ,
    'type({}) ':str(type({})) ,
    'type(NotImplemented)':str(type(NotImplemented)),
    'type(bool()) ':str(type(bool()) ),
    'bool(10) ':str(bool(10)) ,
    'bool(0) ':str(bool(0)) ,
    'bool(-5) ':str(bool(-5)) ,

}  
for ex3, result3 in table3.items():print(f'{ex3:24} = {result3:2}')
# Out:
# float(4)                 = 4.0
# int(5.3)                 =  5
# float("4")               = 4.0
# int("5")                 =  5
# int(True)                =  1
# float(True)              = 1.0
# int(False)               =  0
# float(int(5.3))          = 5.0
# int(5.7)                 =  5
# float(7) // 4            = 1.0
# int(7 / 4)               =  1
# 6.2 and False            =  0
# True and 6.2             = 6.2
# type(4.5)                = <class 'float'>
# type(3)                  = <class 'int'>
# type(True)               = <class 'bool'>
# type(False)              = <class 'bool'>
# type(not 1)              = <class 'bool'>
# type(not(0))             = <class 'bool'>
# type(True and 3)         = <class 'int'>
# type(None)               = <class 'NoneType'>
# type([])                 = <class 'list'>
# type(())                 = <class 'tuple'>
# type({})                 = <class 'dict'>
# type(NotImplemented)     = <class 'NotImplementedType'>
# ...
