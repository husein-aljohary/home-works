# %% [markdown]
# Name:husein aljohary
#
# ID:140083

# %%
#question 1

dic1= {"print(CS+is+fun)":("CS"+"is"+"fun")
       ,"print(CS+(2 * 'is'+fun))":("CS"+(2 * 'is'+"fun"))
       ,"print(Double \") ":('Double "')
       ,"print('Single \'')":('Single \'')
       ,"print('Single ''')":('Single ''')
       ,"print('A' + 'ok')":('A' + 'ok')
       ,"print('A' + str(eval('4 // 2')))":('A' + str(eval('4 // 2')))
       ,"print('A' * 4) ":('A' * 4) 
       ,"print('A' + str(4//2))":('A' + str(4//2))
       ,"print('A' + repr(4//2))":('A' + repr(4//2))
    
}
for k, v in dic1.items():print(k,"-->",v)
# Out:
# print(CS+is+fun) --> CSisfun
# print(CS+(2 * 'is'+fun)) --> CSisisfun
# print(Double ")  --> Double "
# print('Single '') --> Single '
# print('Single ''') --> Single
# print('A' + 'ok') --> Aok
# print('A' + str(eval('4 // 2'))) --> A2
# print('A' * 4)  --> AAAA
# print('A' + str(4//2)) --> A2
# print('A' + repr(4//2)) --> A2

# %%
#question 2
s = 'Hello World!'
dic2= {"print(s[1])":(s[1])
       ,"print(s[1:5])":(s[1:5])
       ,"print(s[:5])":(s[:5])
       ,"print(s[5:])":(s[5:])
       ,"print(s[50:100])":(s[50:100])
       ,"print(s[-1])":(s[-1])
       ,"print(s[-1:5])":(s[-1:5])
       ,"print(s[:-5])":(s[:-5])
       ,"print(s[-5:-1])":(s[-5:-1])
       ,"print(s[-1:-2:-1])":(s[-1:-2:-1])
       ,"print(s[-1:-5:-2])":(s[-1:-5:-2])
       ,"print(s[0:-5])":(s[0:-5])
       ,"print(s[-100:0:-1])":(s[-100:0:-1])
       ,"print('e' in s)":('e' in s)
       ,"print('x' in s)":('x' in s)
       ,"print(s.index('e'))":(s.index('e'))
       ,"print(s.index('l',5))":(s.index('l',5))
       ,"print(s.find('e'))":(s.find('e'))
       ,"print(s.find('x'))":(s.find('x'))
       ,"print(s.count('o'))":(s.count('o'))
    
}
for k2, v2 in dic2.items():print(k2,"-->",v2)
# Out:
# print(s[1]) --> e
# print(s[1:5]) --> ello
# print(s[:5]) --> Hello
# print(s[5:]) -->  World!
# print(s[50:100]) -->
# print(s[-1]) --> !
# print(s[-1:5]) -->
# print(s[:-5]) --> Hello W
# print(s[-5:-1]) --> orld
# print(s[-1:-2:-1]) --> !
# print(s[-1:-5:-2]) --> !l
# print(s[0:-5]) --> Hello W
# print(s[-100:0:-1]) -->
# print('e' in s) --> True
# print('x' in s) --> False
# print(s.index('e')) --> 1
# print(s.index('l',5)) --> 9
# print(s.find('e')) --> 1
# print(s.find('x')) --> -1
# print(s.count('o')) --> 2

# %%
#question 3
alist = ['H','e','l','l','o',' ','W','o','r','l','d','!']

print( "alist.remove('o') print(alist)-->")
alist.remove('o')
print(alist)
print('\n')

print("alist.remove('x') print(alist)-->")
#alist.remove('x')   error
#print(alist)   
print('\n')

print("pos = alist.index('o') print(pos)-->")
pos = alist.index('o')
print(pos)
print('\n')

print("pos = alist.index('B') print(pos)-->")
#pos = alist.index('B')  error
#print(pos)
print('\n')

print("alist[0] = 'J' print(alist)-->")
alist[0] = 'J'
print(alist)
print('\n')

print("alist.insert(4,'o') print(alist)-->")
alist.insert(4,'o')
print(alist)
print('\n')

print("s = alist[:] print(s)-->")
s = alist[:]
print(s)
print('\n')

print("s[0] = 'C' print(s) print(alist)-->")
s[0] = 'C'
print(s)
print(alist)
print('\n')

print("a = '-'.join(s) print(a) print(len(a))-->")
a = '-'.join(s)
print(a)
print(len(a))
print('\n')

print("a = ''.join(s) print(a) print(len(a))-->")
a = ''.join(s)
print(a)
print(len(a))
print('\n')

print("L = list(a) print(L) print(len(L))-->")
L = list(a)
print(L)
print(len(L))
print('\n')

print("t = tuple(L) print(t) print(len(t))-->")
t = tuple(L)
print(t)
print(len(t))
print('\n')

print("s = set(t) print(s) print(len(s))-->")
s = set(t)
print(s)
print(len(s))
# Out:
# alist.remove('o') print(alist)-->
# ['H', 'e', 'l', 'l', ' ', 'W', 'o', 'r', 'l', 'd', '!']
#
#
# alist.remove('x') print(alist)-->
#
#
# pos = alist.index('o') print(pos)-->
# 6
#
#
# pos = alist.index('B') print(pos)-->
#
#
# alist[0] = 'J' print(alist)-->
# ['J', 'e', 'l', 'l', ' ', 'W', 'o', 'r', 'l', 'd', '!']
#
#
# alist.insert(4,'o') print(alist)-->
# ['J', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
#
#
# s = alist[:] print(s)-->
# ['J', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
#
#
# s[0] = 'C' print(s) print(alist)-->
# ['C', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# ['J', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
#
#
# a = '-'.join(s) print(a) print(len(a))-->
# C-e-l-l-o- -W-o-r-l-d-!
# 23
#
#
# a = ''.join(s) print(a) print(len(a))-->
# Cello World!
# 12
#
#
# L = list(a) print(L) print(len(L))-->
# ['C', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# 12
#
#
# t = tuple(L) print(t) print(len(t))-->
# ...
